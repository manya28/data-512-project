# %%
import json, time, requests, config

# %% [markdown]
# General constant parameters for the API request

# %%
# CONSTANTS
#    This is the root of all AQS API URLs
API_REQUEST_URL = 'https://aqs.epa.gov/data/api'
USERNAME = config.username
APIKEY = config.api_key

#    These are some of the 'actions' we can ask the API to take or requests that we can make of the API
#
#    List actions provide information on API parameter values that are required by some other actions/requests
API_ACTION_LIST_CLASSES = '/list/classes?email={email}&key={key}'
API_ACTION_LIST_PARAMS = '/list/parametersByClass?email={email}&key={key}&pc={pclass}'
API_ACTION_LIST_SITES = '/list/sitesByCounty?email={email}&key={key}&state={state}&county={county}'
#
#    Monitor actions are requests for monitoring stations that meet specific criteria
API_ACTION_MONITORS_COUNTY = '/monitors/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_MONITORS_BOX = '/monitors/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    Summary actions are requests for summary data. These are for daily summaries
API_ACTION_DAILY_SUMMARY_COUNTY = '/dailyData/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_DAILY_SUMMARY_BOX = '/dailyData/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
AQI_PARAM_CLASS = "AQI POLLUTANTS"
#   Gaseous AQI pollutants CO, SO2, NO2, and O2
AQI_PARAMS_GASEOUS = "42101,42401,42602,44201"
#   Particulate AQI pollutants PM10, PM2.5, and Acceptable PM2.5
AQI_PARAMS_PARTICULATES = "81102,88101,88502"

#    It is always nice to be respectful of a free data resource.
#    We're going to observe a 100 requests per minute limit - which is fairly nice
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED
#
#    This is a template that covers most of the parameters for the actions we might take, from the set of actions
#    above. In the examples below, most of the time parameters can either be supplied as individual values to a
#    function - or they can be set in a copy of the template and passed in with the template.
# 
AQS_REQUEST_TEMPLATE = {
    "email":      "",     
    "key":        "",      
    "state":      "",     # the two digit state FIPS # as a string
    "county":     "",     # the three digit county FIPS # as a string
    "begin_date": "",     # the start of a time window in YYYYMMDD format
    "end_date":   "",     # the end of a time window in YYYYMMDD format, begin_date and end_date must be in the same year
    "minlat":    0.0,
    "maxlat":    0.0,
    "minlon":    0.0,
    "maxlon":    0.0,
    "param":     "",     # a list of comma separated 5 digit codes, max 5 codes requested
    "pclass":    ""   }   # parameter class is only used by the List calls

CITY_LOCATIONS = {"omaha" : {"city":"Omaha",
               'county': "Douglas",
               "state":"Nebraska",
               "fips": "31055",
               "latlon": [41.26, -96.05]
               }}

# %% [markdown]
# Given our CITY_LOCATION of Omaha, NE, we can now find which monitoring locations are nearby. We will validate the distance of these monitoring location as well, over the years.

# %%
#    This implements the monitors request. This requests monitoring stations. This can be done by state, county, or bounding box. 

def request_monitors(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_MONITORS_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_monitors()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_monitors()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_monitors()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_monitors()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_monitors()'")
    # Note we're not validating FIPS fields because not all of the monitors actions require the FIPS numbers
    
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
    
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#   These are rough estimates for creating bounding boxes based on a city location
#   You can find these rough estimates on the USGS website:
#   https://www.usgs.gov/faqs/how-much-distance-does-a-degree-minute-and-second-cover-your-maps
#
LAT_25MILES = 25.0 * (1.0/69.0)    # This is about 25 miles of latitude in decimal degrees
LON_25MILES = 25.0 * (1.0/54.6)    # This is about 25 miles of longitude in decimal degrees
#
#   Compute rough estimates for a bounding box around a given place
#   The bounding box is scaled in 50 mile increments. That is, the bounding box will have sides that
#   are rough multiples of 50 miles, with the center of the box around the indicated place.
#   The scale parameter determines the scale (size) of the bounding box
#
def bounding_latlon(place=None,scale=1.0):
    minlat = place['latlon'][0] - float(scale) * LAT_25MILES
    maxlat = place['latlon'][0] + float(scale) * LAT_25MILES
    minlon = place['latlon'][1] - float(scale) * LON_25MILES
    maxlon = place['latlon'][1] + float(scale) * LON_25MILES
    return [minlat,maxlat,minlon,maxlon]

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # remember we have both gaseous and particulates
# 
#   We got the monitoring stations for omaha OR above (Deschutes county) - let's work with that one again
request_data['state'] = CITY_LOCATIONS['omaha']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['omaha']['fips'][2:]
#
# the first example uses the default - request monitors by county, we'll just use a recent date for now
response_2020 = request_monitors(request_template=request_data, begin_date="20200701", end_date="20200731")
response_1973 = request_monitors(request_template=request_data, begin_date="19730701", end_date="19730731")
response_1990 = request_monitors(request_template=request_data, begin_date="19900701", end_date="19900731")
#
# the response should be similar to the 'list' request above - but in this case we should only get monitors that
# monitor the AQI_PARAMS_PARTICULATES set of params.
#
for i in [response_2020,response_1973,response_1990]:
    if i["Header"][0]['status'] == "Success":
        print(json.dumps(i['Data'],indent=4))
    else:
        print(json.dumps(i,indent=4))
# Out:
# [
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0019",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "OTHER; POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2011-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9620,
#         "latitude": 41.247486,
#         "longitude": -95.973142,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 372.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "4102 Woolworth Ave. on Healthcenter Warehouse",
#         "address": "DOUGLAS COUNTY HOSP  42ND & WOOLWORTH",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0052",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2009-10-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9652,
#         "latitude": 41.197847,
#         "longitude": -96.056686,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 0.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "ON TOP OF ELEMENTARY SCHOOL",
#         "address": "9225 BERRY",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0028",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1989-01-01",
#         "close_date": "2021-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1989-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9628,
#         "latitude": 41.207958,
#         "longitude": -95.945897,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 357.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "2411 O ST.",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0054",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2001-06-01",
#         "close_date": "2024-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "HIGHEST CONCENTRATION; OTHER",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2001-06-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9654,
#         "latitude": 41.26676,
#         "longitude": -95.93902,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 303.63,
#         "elevation": 0.0,
#         "probe_height": 7.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "19th & Burt",
#         "address": "723 N 18 Street",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0019",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE; QUALITY ASSURANCE",
#         "last_method_code": "545",
#         "last_method_description": "Met One E-SEQ-FRM PM2.5 with VSCC - Gravimetric",
#         "last_method_begin_date": "2020-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9620,
#         "latitude": 41.247486,
#         "longitude": -95.973142,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 372.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "4102 Woolworth Ave. on Healthcenter Warehouse",
#         "address": "DOUGLAS COUNTY HOSP  42ND & WOOLWORTH",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0054",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2001-06-01",
#         "close_date": "2024-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "HIGHEST CONCENTRATION; OTHER",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2001-06-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9654,
#         "latitude": 41.26676,
#         "longitude": -95.93902,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 303.63,
#         "elevation": 0.0,
#         "probe_height": 7.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "19th & Burt",
#         "address": "723 N 18 Street",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0019",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2011-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "122",
#         "last_method_description": "INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION",
#         "last_method_begin_date": "2011-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "PROPOSED NCORE",
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9620,
#         "latitude": 41.247486,
#         "longitude": -95.973142,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 372.0,
#         "probe_height": 10.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "4102 Woolworth Ave. on Healthcenter Warehouse",
#         "address": "DOUGLAS COUNTY HOSP  42ND & WOOLWORTH",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0052",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE; QUALITY ASSURANCE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2014-10-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9652,
#         "latitude": 41.197847,
#         "longitude": -96.056686,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 0.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "ON TOP OF ELEMENTARY SCHOOL",
#         "address": "9225 BERRY",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]
# {
#     "Header": [
#         {
#             "status": "No data matched your selection",
#             "request_time": "2024-10-30T04:33:38-04:00",
#             "url": "https://aqs.epa.gov/data/api/monitors/byCounty?email=manyac@uw.edu&key=mauvegoose66&param=81102,88101,88502&bdate=19730701&edate=19730731&state=31&county=055",
#             "rows": 0
#         }
#     ],
#     "Data": []
# }
# [
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0028",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1989-01-01",
#         "close_date": "2021-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1989-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9628,
#         "latitude": 41.207958,
#         "longitude": -95.945897,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 357.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "2411 O ST.",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0020",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1990-01-01",
#         "close_date": "1992-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1990-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9621,
#         "latitude": 41.232499,
#         "longitude": -96.010294,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 320.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "63RD & FREDRICK  UTIL DIST BLDG",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0040",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1987-10-01",
#         "close_date": "2010-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1987-10-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9640,
#         "latitude": 41.25861,
#         "longitude": -96.033628,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 315.0,
#         "probe_height": 5.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "7717 DODGE",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0011",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-02-01",
#         "close_date": "2001-05-25",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1985-02-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9614,
#         "latitude": 41.270276,
#         "longitude": -95.93057,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 305.0,
#         "probe_height": 7.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "PUBLIC WORKS BLDG  11TH & NICHOLAS",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0011",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-01-01",
#         "close_date": "2001-05-25",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1985-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9614,
#         "latitude": 41.270276,
#         "longitude": -95.93057,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 305.0,
#         "probe_height": 7.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "PUBLIC WORKS BLDG  11TH & NICHOLAS",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %%
print(f"Number of monitoring stations returned for 2020 is: {len(response_2020['Data'])}")
print(f"Number of monitoring stations returned for 1990 is: {len(response_1990['Data'])}")
print(f"Number of monitoring stations returned for 1973 is: {len(response_1973['Data'])}")
# Out:
# Number of monitoring stations returned for 2020 is: 8
# Number of monitoring stations returned for 1990 is: 5
# Number of monitoring stations returned for 1973 is: 0

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # same particulate request as the one abover
# 
#   Not going to use these - comment them out
#request_data['state'] = CITY_LOCATIONS['bend']['fips'][:2]
#request_data['county'] = CITY_LOCATIONS['bend']['fips'][2:]
#
#   Now, we need bounding box parameters

#   50 mile box
bbox = bounding_latlon(CITY_LOCATIONS['omaha'],scale=1.0)
#   100 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=2.0)
#   150 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=3.0)
#   200 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=4.0)

# the bbox response comes back as a list - [minlat,maxlat,minlon,maxlon]

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#   we need to change the action for the API from the default to the bounding box - same recent date for now
response_2020 = request_monitors(request_template=request_data, begin_date="20200701", end_date="20200731",
                            endpoint_action = API_ACTION_MONITORS_BOX)
response_1990 = request_monitors(request_template=request_data, begin_date="19900701", end_date="19900731",
                            endpoint_action = API_ACTION_MONITORS_BOX)
response_1973 = request_monitors(request_template=request_data, begin_date="19730701", end_date="19730731",
                            endpoint_action = API_ACTION_MONITORS_BOX)

for i in [response_2020,response_1973,response_1990]:
    if i["Header"][0]['status'] == "Success":
        print(json.dumps(i['Data'],indent=4))
    else:
        print(json.dumps(i,indent=4))
# Out:
# [
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0019",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "OTHER; POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2011-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9620,
#         "latitude": 41.247486,
#         "longitude": -95.973142,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 372.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "4102 Woolworth Ave. on Healthcenter Warehouse",
#         "address": "DOUGLAS COUNTY HOSP  42ND & WOOLWORTH",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0052",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2009-10-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9652,
#         "latitude": 41.197847,
#         "longitude": -96.056686,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 0.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "ON TOP OF ELEMENTARY SCHOOL",
#         "address": "9225 BERRY",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0028",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1989-01-01",
#         "close_date": "2021-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1989-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9628,
#         "latitude": 41.207958,
#         "longitude": -95.945897,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 357.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "2411 O ST.",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0054",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2001-06-01",
#         "close_date": "2024-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "HIGHEST CONCENTRATION; OTHER",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2001-06-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9654,
#         "latitude": 41.26676,
#         "longitude": -95.93902,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 303.63,
#         "elevation": 0.0,
#         "probe_height": 7.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "19th & Burt",
#         "address": "723 N 18 Street",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "19",
#         "county_code": "155",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-07-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2006-10-02",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "1080",
#         "monitoring_agency": "University Hygenic Laboratory (University of Iowa)",
#         "si_id": 5278,
#         "latitude": 41.264171,
#         "longitude": -95.896124,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 301.0,
#         "probe_height": 10.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "COUNCIL BLUFFS, FRANKLIN SCH.",
#         "address": "3130 C AVE. COUNCIL BLUFFS",
#         "state_name": "Iowa",
#         "county_name": "Pottawattamie",
#         "city_name": "Council Bluffs",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0019",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE; QUALITY ASSURANCE",
#         "last_method_code": "545",
#         "last_method_description": "Met One E-SEQ-FRM PM2.5 with VSCC - Gravimetric",
#         "last_method_begin_date": "2020-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "NCORE",
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9620,
#         "latitude": 41.247486,
#         "longitude": -95.973142,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 372.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "4102 Woolworth Ave. on Healthcenter Warehouse",
#         "address": "DOUGLAS COUNTY HOSP  42ND & WOOLWORTH",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0054",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2001-06-01",
#         "close_date": "2024-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "HIGHEST CONCENTRATION; OTHER",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2001-06-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9654,
#         "latitude": 41.26676,
#         "longitude": -95.93902,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 303.63,
#         "elevation": 0.0,
#         "probe_height": 7.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "19th & Burt",
#         "address": "723 N 18 Street",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "19",
#         "county_code": "155",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2013-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2013-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "1080",
#         "monitoring_agency": "University Hygenic Laboratory (University of Iowa)",
#         "si_id": 5278,
#         "latitude": 41.264171,
#         "longitude": -95.896124,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 301.0,
#         "probe_height": 10.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "COUNCIL BLUFFS, FRANKLIN SCH.",
#         "address": "3130 C AVE. COUNCIL BLUFFS",
#         "state_name": "Iowa",
#         "county_name": "Pottawattamie",
#         "city_name": "Council Bluffs",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "19",
#         "county_code": "155",
#         "site_number": "0009",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1999-12-01",
#         "close_date": "2023-07-01",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "127",
#         "last_method_description": "R - P Co Partisol Model 2025 - Gravimetric",
#         "last_method_begin_date": "2004-08-31",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1080",
#         "monitoring_agency": "University Hygenic Laboratory (University of Iowa)",
#         "si_id": 5278,
#         "latitude": 41.264171,
#         "longitude": -95.896124,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 301.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "COUNCIL BLUFFS, FRANKLIN SCH.",
#         "address": "3130 C AVE. COUNCIL BLUFFS",
#         "state_name": "Iowa",
#         "county_name": "Pottawattamie",
#         "city_name": "Council Bluffs",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "177",
#         "site_number": "0002",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-04-06",
#         "close_date": "2022-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2009-10-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9717,
#         "latitude": 41.551211,
#         "longitude": -96.146175,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 0.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "ON ROOF OF GOOD SHEPARD LUTHERAN HOME",
#         "address": "2242 WRIGHT STREET",
#         "state_name": "Nebraska",
#         "county_name": "Washington",
#         "city_name": "Blair",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0019",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2011-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "122",
#         "last_method_description": "INSTRUMENT MET ONE 4 MODELS - BETA ATTENUATION",
#         "last_method_begin_date": "2011-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "PROPOSED NCORE",
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9620,
#         "latitude": 41.247486,
#         "longitude": -95.973142,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 372.0,
#         "probe_height": 10.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "4102 Woolworth Ave. on Healthcenter Warehouse",
#         "address": "DOUGLAS COUNTY HOSP  42ND & WOOLWORTH",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0052",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE; QUALITY ASSURANCE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2014-10-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9652,
#         "latitude": 41.197847,
#         "longitude": -96.056686,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 0.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "ON TOP OF ELEMENTARY SCHOOL",
#         "address": "9225 BERRY",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "153",
#         "site_number": "0007",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2010-07-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2010-07-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9709,
#         "latitude": 41.133294,
#         "longitude": -95.956103,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 0.0,
#         "probe_height": 9.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "ON GOLDEN HILLS ELEMENTARY ROOF",
#         "address": "2912 COFFEY AVE  BELLEVUE",
#         "state_name": "Nebraska",
#         "county_name": "Sarpy",
#         "city_name": "Bellevue",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]
# {
#     "Header": [
#         {
#             "status": "No data matched your selection",
#             "request_time": "2024-10-30T04:46:44-04:00",
#             "url": "https://aqs.epa.gov/data/api/monitors/byBox?email=manyac@uw.edu&key=mauvegoose66&param=81102,88101,88502&bdate=19730701&edate=19730731&minlat=40.89768115942029&maxlat=41.62231884057971&minlon=-96.50787545787546&maxlon=-95.59212454212454",
#             "rows": 0
#         }
#     ],
#     "Data": []
# }
# [
#     {
#         "state_code": "31",
#         "county_code": "025",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-01-01",
#         "close_date": "1999-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1985-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0752",
#         "monitoring_agency": "Nebraska Department Of Environmental Control",
#         "si_id": 9584,
#         "latitude": 41.00111,
#         "longitude": -96.161958,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 317.0,
#         "probe_height": 3.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "LIBRARY, LOUISVILLE",
#         "state_name": "Nebraska",
#         "county_name": "Cass",
#         "city_name": "Not in a city",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "025",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-01-01",
#         "close_date": "1999-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1985-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0752",
#         "monitoring_agency": "Nebraska Department Of Environmental Control",
#         "si_id": 9584,
#         "latitude": 41.00111,
#         "longitude": -96.161958,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 317.0,
#         "probe_height": 3.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "LIBRARY, LOUISVILLE",
#         "state_name": "Nebraska",
#         "county_name": "Cass",
#         "city_name": "Not in a city",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0028",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1989-01-01",
#         "close_date": "2021-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1989-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9628,
#         "latitude": 41.207958,
#         "longitude": -95.945897,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 357.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "2411 O ST.",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "19",
#         "county_code": "155",
#         "site_number": "0024",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1987-04-01",
#         "close_date": "1996-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "064",
#         "last_method_description": "HI-VOL-SA/GMW-321-B - GRAVIMETRIC",
#         "last_method_begin_date": "1987-04-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1080",
#         "monitoring_agency": "University Hygenic Laboratory (University of Iowa)",
#         "si_id": 5290,
#         "latitude": 41.270831,
#         "longitude": -95.881123,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 299.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "1015 NORTH 25TH STREET COUNCIL BLUFFS",
#         "state_name": "Iowa",
#         "county_name": "Pottawattamie",
#         "city_name": "Council Bluffs",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0020",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1990-01-01",
#         "close_date": "1992-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1990-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9621,
#         "latitude": 41.232499,
#         "longitude": -96.010294,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 320.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "63RD & FREDRICK  UTIL DIST BLDG",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0040",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1987-10-01",
#         "close_date": "2010-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1987-10-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9640,
#         "latitude": 41.25861,
#         "longitude": -96.033628,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 315.0,
#         "probe_height": 5.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "7717 DODGE",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0011",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-02-01",
#         "close_date": "2001-05-25",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1985-02-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9614,
#         "latitude": 41.270276,
#         "longitude": -95.93057,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 305.0,
#         "probe_height": 7.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "PUBLIC WORKS BLDG  11TH & NICHOLAS",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "19",
#         "county_code": "155",
#         "site_number": "0024",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-01-01",
#         "close_date": "1996-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "052",
#         "last_method_description": "HI-VOL-SA321A - GRAVIMETRIC",
#         "last_method_begin_date": "1985-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1080",
#         "monitoring_agency": "University Hygenic Laboratory (University of Iowa)",
#         "si_id": 5290,
#         "latitude": 41.270831,
#         "longitude": -95.881123,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 299.0,
#         "probe_height": 5.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "1015 NORTH 25TH STREET COUNCIL BLUFFS",
#         "state_name": "Iowa",
#         "county_name": "Pottawattamie",
#         "city_name": "Council Bluffs",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "31",
#         "county_code": "055",
#         "site_number": "0011",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-01-01",
#         "close_date": "2001-05-25",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1985-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0816",
#         "monitoring_agency": "Omaha-Douglas County Health Department",
#         "si_id": 9614,
#         "latitude": 41.270276,
#         "longitude": -95.93057,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 305.0,
#         "probe_height": 7.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "PUBLIC WORKS BLDG  11TH & NICHOLAS",
#         "state_name": "Nebraska",
#         "county_name": "Douglas",
#         "city_name": "Omaha",
#         "cbsa_code": "36540",
#         "cbsa_name": "Omaha-Council Bluffs, NE-IA",
#         "csa_code": "420",
#         "csa_name": "Omaha-Council Bluffs-Fremont, NE-IA",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %%
print(f"Number of monitoring stations within 50 miles of Omaha, NE returned for 2020 is: {len(response_2020['Data'])}")
print(f"Number of monitoring stations within 50 miles of Omaha, NE returned for 1990 is: {len(response_1990['Data'])}")
print(f"Number of monitoring stations within 50 miles of Omaha, NE returned for 1973 is: {len(response_1973['Data'])}")
# Out:
# Number of monitoring stations within 50 miles of Omaha, NE returned for 2020 is: 13
# Number of monitoring stations within 50 miles of Omaha, NE returned for 1990 is: 9
# Number of monitoring stations within 50 miles of Omaha, NE returned for 1973 is: 0

# %%
#   This implements the daily summary request. Daily summary provides a daily summary value for each sensor being requested
#    from the start date to the end date. 
#
def request_daily_summary(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_DAILY_SUMMARY_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_daily_summary()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_daily_summary()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_daily_summary()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_daily_summary()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_daily_summary()'")
    # Note we're not validating FIPS fields because not all of the daily summary actions require the FIPS numbers
        
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY

#   We got the monitoring stations for omaha 
request_data['state'] = CITY_LOCATIONS['omaha']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['omaha']['fips'][2:]

gaseous_aqi = {}
particulate_aqi = {}

# Loop through 1973 (year of creation of US EPA) to 2021
for year in range(1970, 2022):

    # Fire season dates
    start = f"{year}0501"  # May 01
    end = f"{year}1031"     # October 31
    
    # Call the function with the specific date range for this year
    request_data['param'] = AQI_PARAMS_GASEOUS
    print("Daily Gas Summary")
    yearly_gaseous_aqi = request_daily_summary(request_template=request_data, begin_date=start, end_date=end)

    request_data['param'] = AQI_PARAMS_PARTICULATES
    print("Daily Particulate Summary")
    yearly_particulate_aqi = request_daily_summary(request_template=request_data, begin_date=start, end_date=end)
    
    # Append the data for this year to the list
    print("Building Dictionaries...")
    gaseous_aqi[year] = yearly_gaseous_aqi
    particulate_aqi[year] = yearly_particulate_aqi
# Out:
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...
# Daily Gas Summary
# Daily Particulate Summary
# Building Dictionaries...

# %%
with open("particulate_aqi.json",'w') as f:
    json.dump(particulate_aqi,f)

# %%
with open("gaseous_aqi.json", 'w') as f:
    json.dump(gaseous_aqi,f)
